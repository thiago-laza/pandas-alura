# %% [markdown]
# ---

# %%
import pandas as pd

# %%
dados = pd.read_csv('learning_matematica.csv', sep=';')
dados
# Out:
#       Nome_Aluno  Idade  Nota_Algebra  Nota_Geometria  Nota_Numeros  \
# 0    Estudante_1     16           NaN        7.179975      7.753990
# 1    Estudante_2     13      8.601622             NaN      8.540739
# 2    Estudante_3     15      5.000572        7.748312      6.454524
# 3    Estudante_4     15      6.511663        7.176612           NaN
# 4    Estudante_5     14      5.733779        7.101839      9.464735
# 5    Estudante_6     17           NaN             NaN      9.481465
# 6    Estudante_7     12      5.931301        6.023243      5.627927
# 7    Estudante_8     12      6.727804             NaN      6.036214
# 8    Estudante_9     12      6.983837        6.498273      5.257336
# 9   Estudante_10     13      7.694084        6.334136      7.204049
# 10  Estudante_11     13      7.095973        8.105669      5.149381
# 11  Estudante_12     16      8.426098        7.645710      7.284166
# 12  Estudante_13     16      6.022261        5.672900      8.245720
# ...

# %% [markdown]
# ---

# %% [markdown]
# Conhecendo os dados

# %%
dados.shape
# Out:
# (50, 11)

# %%
dados.columns
# Out:
# Index(['Nome_Aluno', 'Idade', 'Nota_Algebra', 'Nota_Geometria', 'Nota_Numeros',
#        'Nota_Grandezas', 'Nota_Estatistica', 'Nota_Probabilidade',
#        'Horas_Estudadas_Semana', 'Participacao_Grupo_Estudo',
#        'Uso_Plataforma_Online'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Nome_Aluno                 50 non-null     object
#  1   Idade                      50 non-null     int64
#  2   Nota_Algebra               46 non-null     float64
#  3   Nota_Geometria             43 non-null     float64
#  4   Nota_Numeros               46 non-null     float64
#  5   Nota_Grandezas             47 non-null     float64
#  6   Nota_Estatistica           43 non-null     float64
#  7   Nota_Probabilidade         46 non-null     float64
#  8   Horas_Estudadas_Semana     50 non-null     int64
#  9   Participacao_Grupo_Estudo  50 non-null     int64
#  10  Uso_Plataforma_Online      50 non-null     int64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 4.4+ KB

# %%
dados.describe().T
# Out:
#                            count       mean       std        min        25%  \
# Idade                       50.0  14.660000  1.697657  12.000000  13.000000
# Nota_Algebra                46.0   7.448289  1.539823   5.000572   5.998446
# Nota_Geometria              43.0   7.370839  1.237914   5.326433   6.416205
# Nota_Numeros                46.0   7.365859  1.263394   5.149381   6.398687
# Nota_Grandezas              47.0   7.643939  1.484196   5.031151   6.266655
# Nota_Estatistica            43.0   7.392005  1.519495   5.008211   6.066372
# Nota_Probabilidade          46.0   7.764629  1.328131   5.208483   6.899748
# Horas_Estudadas_Semana      50.0   4.880000  2.715338   1.000000   3.000000
# Participacao_Grupo_Estudo   50.0   0.560000  0.501427   0.000000   0.000000
# Uso_Plataforma_Online       50.0   0.720000  0.453557   0.000000   0.000000
#
#                                  50%        75%        max
# Idade                      15.000000  16.000000  17.000000
# ...

# %% [markdown]
# ---

# %% [markdown]
# Observados as informacoes que serao usada para o estudo

# %%
df_estudo = dados.drop(columns=["Horas_Estudadas_Semana", "Participacao_Grupo_Estudo", "Uso_Plataforma_Online"])
df_estudo
# Out:
#       Nome_Aluno  Idade  Nota_Algebra  Nota_Geometria  Nota_Numeros  \
# 0    Estudante_1     16           NaN        7.179975      7.753990
# 1    Estudante_2     13      8.601622             NaN      8.540739
# 2    Estudante_3     15      5.000572        7.748312      6.454524
# 3    Estudante_4     15      6.511663        7.176612           NaN
# 4    Estudante_5     14      5.733779        7.101839      9.464735
# 5    Estudante_6     17           NaN             NaN      9.481465
# 6    Estudante_7     12      5.931301        6.023243      5.627927
# 7    Estudante_8     12      6.727804             NaN      6.036214
# 8    Estudante_9     12      6.983837        6.498273      5.257336
# 9   Estudante_10     13      7.694084        6.334136      7.204049
# 10  Estudante_11     13      7.095973        8.105669      5.149381
# 11  Estudante_12     16      8.426098        7.645710      7.284166
# 12  Estudante_13     16      6.022261        5.672900      8.245720
# ...

# %% [markdown]
# ---

# %% [markdown]
# Filtrando os dados

# %%
df_estudo.isnull().sum()
# Out:
# Nome_Aluno            0
# Idade                 0
# Nota_Algebra          4
# Nota_Geometria        7
# Nota_Numeros          4
# Nota_Grandezas        3
# Nota_Estatistica      7
# Nota_Probabilidade    4
# dtype: int64

# %%
df_estudo = df_estudo.fillna(0)

# %%
df_estudo.isnull().sum()
# Out:
# Nome_Aluno            0
# Idade                 0
# Nota_Algebra          0
# Nota_Geometria        0
# Nota_Numeros          0
# Nota_Grandezas        0
# Nota_Estatistica      0
# Nota_Probabilidade    0
# dtype: int64

# %%
registro_a_remover = df_estudo.query('Nota_Algebra == 0 | Nota_Geometria == 0 | Nota_Numeros == 0 | Nota_Grandezas == 0 | Nota_Estatistica == 0 | Nota_Probabilidade == 0').index

# %%
df_estudo.drop(registro_a_remover, axis=0, inplace=True)

# %%
df_estudo
# Out:
#       Nome_Aluno  Idade  Nota_Algebra  Nota_Geometria  Nota_Numeros  \
# 4    Estudante_5     14      5.733779        7.101839      9.464735
# 6    Estudante_7     12      5.931301        6.023243      5.627927
# 8    Estudante_9     12      6.983837        6.498273      5.257336
# 9   Estudante_10     13      7.694084        6.334136      7.204049
# 10  Estudante_11     13      7.095973        8.105669      5.149381
# 11  Estudante_12     16      8.426098        7.645710      7.284166
# 12  Estudante_13     16      6.022261        5.672900      8.245720
# 13  Estudante_14     15      9.390587        7.567891      6.392436
# 18  Estudante_19     15      5.701935        9.232807      6.296262
# 19  Estudante_20     16      5.990507        5.398227      7.075506
# 21  Estudante_22     16      9.841308        5.326433      8.465690
# 23  Estudante_24     15      8.461613        5.482655      5.784339
# 28  Estudante_29     12      5.849152        6.101531      6.939856
# ...

# %% [markdown]
# ---

# %% [markdown]
# Estudando as variaveis separadamente

# %% [markdown]
# ALGEBRA

# %%
df_estudo['Nota_Algebra']
# Out:
# 4     5.733779
# 6     5.931301
# 8     6.983837
# 9     7.694084
# 10    7.095973
# 11    8.426098
# 12    6.022261
# 13    9.390587
# 18    5.701935
# 19    5.990507
# 21    9.841308
# 23    8.461613
# 28    5.849152
# 29    9.390713
# 32    9.789448
# 34    8.459386
# 35    6.577578
# 36    8.432505
# 37    9.173128
# 38    5.091441
# 40    9.944305
# 42    6.402220
# 43    8.946397
# 45    7.239468
# 46    9.542978
# 49    5.650143
# Name: Nota_Algebra, dtype: float64

# %%
df_estudo['Nota_Algebra'].mean()
# Out:
# 7.606236291587306

# %%
acima_media_algebra = df_estudo['Nota_Algebra'] > df_estudo['Nota_Algebra'].mean()

# %%
df_estudo[acima_media_algebra]['Nota_Algebra']
# Out:
# 9     7.694084
# 11    8.426098
# 13    9.390587
# 21    9.841308
# 23    8.461613
# 29    9.390713
# 32    9.789448
# 34    8.459386
# 36    8.432505
# 37    9.173128
# 40    9.944305
# 43    8.946397
# 46    9.542978
# Name: Nota_Algebra, dtype: float64

# %%
abaixo_media_algebra = df_estudo['Nota_Algebra'] <= df_estudo['Nota_Algebra'].mean()

# %%
df_estudo[abaixo_media_algebra]['Nota_Algebra']
# Out:
# 4     5.733779
# 6     5.931301
# 8     6.983837
# 10    7.095973
# 12    6.022261
# 18    5.701935
# 19    5.990507
# 28    5.849152
# 35    6.577578
# 38    5.091441
# 42    6.402220
# 45    7.239468
# 49    5.650143
# Name: Nota_Algebra, dtype: float64

# %% [markdown]
# ESTATISTICA

# %%
df_estudo['Nota_Estatistica']
# Out:
# 4     7.442056
# 6     8.829539
# 8     6.484003
# 9     5.938606
# 10    5.403706
# 11    8.692201
# 12    7.206546
# 13    5.791549
# 18    8.143940
# 19    7.899189
# 21    6.329096
# 23    6.267941
# 28    9.801134
# 29    5.942073
# 32    8.499218
# 34    5.114665
# 35    7.888314
# 36    5.008211
# 37    7.577363
# 38    8.198976
# 40    6.295488
# 42    9.352415
# 43    9.613748
# 45    7.347442
# 46    9.907344
# 49    7.732282
# Name: Nota_Estatistica, dtype: float64

# %%
df_estudo['Nota_Estatistica'].mean()
# Out:
# 7.411809475862891

# %%
acima_media_estatistica = df_estudo['Nota_Estatistica'] > df_estudo['Nota_Estatistica'].mean()

# %%
df_estudo[acima_media_estatistica]['Nota_Estatistica']
# Out:
# 4     7.442056
# 6     8.829539
# 11    8.692201
# 18    8.143940
# 19    7.899189
# 28    9.801134
# 32    8.499218
# 35    7.888314
# 37    7.577363
# 38    8.198976
# 42    9.352415
# 43    9.613748
# 46    9.907344
# 49    7.732282
# Name: Nota_Estatistica, dtype: float64

# %%
abaixo_media_estatistica = df_estudo['Nota_Estatistica'] <= df_estudo['Nota_Estatistica'].mean()

# %%
df_estudo[abaixo_media_estatistica]['Nota_Estatistica']
# Out:
# 8     6.484003
# 9     5.938606
# 10    5.403706
# 12    7.206546
# 13    5.791549
# 21    6.329096
# 23    6.267941
# 29    5.942073
# 34    5.114665
# 36    5.008211
# 40    6.295488
# 45    7.347442
# Name: Nota_Estatistica, dtype: float64

# %% [markdown]
# GEOMETRIA

# %%
df_estudo['Nota_Geometria']
# Out:
# 4     7.101839
# 6     6.023243
# 8     6.498273
# 9     6.334136
# 10    8.105669
# 11    7.645710
# 12    5.672900
# 13    7.567891
# 18    9.232807
# 19    5.398227
# 21    5.326433
# 23    5.482655
# 28    6.101531
# 29    6.749131
# 32    8.202034
# 34    7.526184
# 35    6.934463
# 36    8.968187
# 37    7.900021
# 38    5.811493
# 40    9.822755
# 42    9.447600
# 43    6.708068
# 45    7.137730
# 46    7.183736
# 49    9.768711
# Name: Nota_Geometria, dtype: float64

# %%
df_estudo['Nota_Geometria'].mean()
# Out:
# 7.25582419830685

# %%
acima_media_geometria = df_estudo['Nota_Geometria'] > df_estudo['Nota_Geometria'].mean()

# %%
df_estudo[acima_media_geometria]['Nota_Geometria']
# Out:
# 10    8.105669
# 11    7.645710
# 13    7.567891
# 18    9.232807
# 32    8.202034
# 34    7.526184
# 36    8.968187
# 37    7.900021
# 40    9.822755
# 42    9.447600
# 49    9.768711
# Name: Nota_Geometria, dtype: float64

# %%
abaixo_media_geometria = df_estudo['Nota_Geometria'] <= df_estudo['Nota_Geometria'].mean()

# %%
df_estudo[abaixo_media_geometria]['Nota_Geometria']
# Out:
# 4     7.101839
# 6     6.023243
# 8     6.498273
# 9     6.334136
# 12    5.672900
# 19    5.398227
# 21    5.326433
# 23    5.482655
# 28    6.101531
# 29    6.749131
# 35    6.934463
# 38    5.811493
# 43    6.708068
# 45    7.137730
# 46    7.183736
# Name: Nota_Geometria, dtype: float64

# %% [markdown]
# GRANDEZAS

# %%
df_estudo['Nota_Grandezas']
# Out:
# 4     8.488644
# 6     9.881372
# 8     6.264912
# 9     7.173958
# 10    8.896915
# 11    5.988425
# 12    9.314966
# 13    9.917003
# 18    5.220800
# 19    9.783265
# 21    9.744887
# 23    9.331446
# 28    8.666901
# 29    7.042219
# 32    7.608481
# 34    5.791117
# 35    7.726013
# 36    7.622020
# 37    8.188051
# 38    7.007477
# 40    6.984500
# 42    8.837025
# 43    5.894870
# 45    7.512665
# 46    8.433335
# 49    8.124654
# Name: Nota_Grandezas, dtype: float64

# %%
df_estudo['Nota_Grandezas'].mean()
# Out:
# 7.901766260473

# %%
acima_media_grandeza = df_estudo['Nota_Grandezas'] > df_estudo['Nota_Grandezas'].mean()

# %%
df_estudo[acima_media_grandeza]['Nota_Grandezas']
# Out:
# 4     8.488644
# 6     9.881372
# 10    8.896915
# 12    9.314966
# 13    9.917003
# 19    9.783265
# 21    9.744887
# 23    9.331446
# 28    8.666901
# 37    8.188051
# 42    8.837025
# 46    8.433335
# 49    8.124654
# Name: Nota_Grandezas, dtype: float64

# %%
abaixo_media_grandeza = df_estudo['Nota_Grandezas'] <= df_estudo['Nota_Grandezas'].mean()

# %%
df_estudo[abaixo_media_grandeza]['Nota_Grandezas']
# Out:
# 8     6.264912
# 9     7.173958
# 11    5.988425
# 18    5.220800
# 29    7.042219
# 32    7.608481
# 34    5.791117
# 35    7.726013
# 36    7.622020
# 38    7.007477
# 40    6.984500
# 43    5.894870
# 45    7.512665
# Name: Nota_Grandezas, dtype: float64

# %% [markdown]
# NUMEROS

# %%
df_estudo['Nota_Numeros']
# Out:
# 4     9.464735
# 6     5.627927
# 8     5.257336
# 9     7.204049
# 10    5.149381
# 11    7.284166
# 12    8.245720
# 13    6.392436
# 18    6.296262
# 19    7.075506
# 21    8.465690
# 23    5.784339
# 28    6.939856
# 29    9.681918
# 32    9.514171
# 34    6.889970
# 35    5.461085
# 36    8.267055
# 37    7.789204
# 38    6.807824
# 40    7.032600
# 42    6.346178
# 43    6.458964
# 45    9.302670
# 46    7.931265
# 49    7.273110
# Name: Nota_Numeros, dtype: float64

# %%
df_estudo['Nota_Numeros'].mean()
# Out:
# 7.2285928911391455

# %%
acima_media_numeros = df_estudo['Nota_Numeros'] > df_estudo['Nota_Numeros'].mean()

# %%
df_estudo[acima_media_numeros]['Nota_Numeros']
# Out:
# 4     9.464735
# 11    7.284166
# 12    8.245720
# 21    8.465690
# 29    9.681918
# 32    9.514171
# 36    8.267055
# 37    7.789204
# 45    9.302670
# 46    7.931265
# 49    7.273110
# Name: Nota_Numeros, dtype: float64

# %%
abaixo_media_numeros = df_estudo['Nota_Numeros'] <= df_estudo['Nota_Numeros'].mean()

# %%
df_estudo[abaixo_media_numeros]['Nota_Numeros']
# Out:
# 6     5.627927
# 8     5.257336
# 9     7.204049
# 10    5.149381
# 13    6.392436
# 18    6.296262
# 19    7.075506
# 23    5.784339
# 28    6.939856
# 34    6.889970
# 35    5.461085
# 38    6.807824
# 40    7.032600
# 42    6.346178
# 43    6.458964
# Name: Nota_Numeros, dtype: float64

# %% [markdown]
# PROBABILIDADE

# %%
df_estudo['Nota_Probabilidade']
# Out:
# 4     5.538283
# 6     7.649087
# 8     6.677039
# 9     8.112597
# 10    7.190707
# 11    8.679411
# 12    7.590182
# 13    7.894293
# 18    9.381338
# 19    9.118797
# 21    8.593186
# 23    8.682033
# 28    7.016281
# 29    6.084756
# 32    6.278070
# 34    7.995030
# 35    8.586661
# 36    9.686748
# 37    6.759049
# 38    6.268170
# 40    8.732554
# 42    7.030539
# 43    9.946899
# 45    6.869042
# 46    8.548143
# 49    8.854405
# Name: Nota_Probabilidade, dtype: float64

# %%
df_estudo['Nota_Probabilidade'].mean()
# Out:
# 7.837050034335527

# %%
acima_media_probabilidade = df_estudo['Nota_Probabilidade'] > df_estudo['Nota_Probabilidade'].mean()

# %%
df_estudo[acima_media_probabilidade]['Nota_Probabilidade']
# Out:
# 9     8.112597
# 11    8.679411
# 13    7.894293
# 18    9.381338
# 19    9.118797
# 21    8.593186
# 23    8.682033
# 34    7.995030
# 35    8.586661
# 36    9.686748
# 40    8.732554
# 43    9.946899
# 46    8.548143
# 49    8.854405
# Name: Nota_Probabilidade, dtype: float64

# %%
abaixo_media_probabilidade = df_estudo['Nota_Probabilidade'] <= df_estudo['Nota_Probabilidade'].mean()

# %%
df_estudo[abaixo_media_probabilidade]['Nota_Probabilidade']
# Out:
# 4     5.538283
# 6     7.649087
# 8     6.677039
# 10    7.190707
# 12    7.590182
# 28    7.016281
# 29    6.084756
# 32    6.278070
# 37    6.759049
# 38    6.268170
# 42    7.030539
# 45    6.869042
# Name: Nota_Probabilidade, dtype: float64

# %%
df_estudo['Media'] = df_estudo.loc[:, 'Nota_Algebra':'Nota_Probabilidade'].mean(axis=1)

# %% [markdown]
# Acrescentando a coluna media

# %%
df_estudo
# Out:
#       Nome_Aluno  Idade  Nota_Algebra  Nota_Geometria  Nota_Numeros  \
# 4    Estudante_5     14      5.733779        7.101839      9.464735
# 6    Estudante_7     12      5.931301        6.023243      5.627927
# 8    Estudante_9     12      6.983837        6.498273      5.257336
# 9   Estudante_10     13      7.694084        6.334136      7.204049
# 10  Estudante_11     13      7.095973        8.105669      5.149381
# 11  Estudante_12     16      8.426098        7.645710      7.284166
# 12  Estudante_13     16      6.022261        5.672900      8.245720
# 13  Estudante_14     15      9.390587        7.567891      6.392436
# 18  Estudante_19     15      5.701935        9.232807      6.296262
# 19  Estudante_20     16      5.990507        5.398227      7.075506
# 21  Estudante_22     16      9.841308        5.326433      8.465690
# 23  Estudante_24     15      8.461613        5.482655      5.784339
# 28  Estudante_29     12      5.849152        6.101531      6.939856
# ...
